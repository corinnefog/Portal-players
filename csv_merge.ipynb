# %%
import pandas as pd
import numpy as np

# %%
June4 = pd.read_csv('~/Downloads/Tomsox Data/Pitching Charts/TomSox 6-4-2025- Chart (Dropdown).csv')
June4.head()
# Out:
#    P # Pitcher  Unnamed: 2  Outs    # L/R Pitch          S/B  Zone Result  \
# 0    1  Gibson         NaN   0.0  1.0   L    FB         Ball   NaN    NaN
# 1    2  Gibson         NaN   0.0  1.0   L    FB          BIP   NaN     2B
# 2    3  Gibson         NaN   0.0  1.0   R    FB          BIP   NaN      K
# 3    4  Gibson         NaN   0.0  1.0   R    CH         Ball   NaN    NaN
# 4    5  Gibson         NaN   1.0  1.0   R    FB  Strike-Take   NaN    NaN
#
#    ...  Strikes.1  COUNT Unnamed: 27   P  LOM\nOut LOM Scored  1-2-3  2&3  \
# 0  ...        NaN    0-0         NaN NaN       NaN        NaN    NaN  NaN
# 1  ...        NaN    1-0         NaN NaN       NaN        NaN    NaN  NaN
# 2  ...        NaN    0-0         NaN NaN       NaN        NaN    NaN  NaN
# 3  ...        NaN    0-0         NaN NaN       NaN        NaN    NaN  NaN
# 4  ...        1.0    1-0         NaN NaN       NaN        NaN    NaN  NaN
#
#    0-1 R  FU IP
# 0    NaN    NaN
# 1    NaN    NaN
# 2    NaN    NaN
# ...

# %%
June4.columns
# Out:
# Index(['P #', 'Pitcher', 'Unnamed: 2', 'Outs', '#', 'L/R', 'Pitch', 'S/B',
#        'Zone', 'Result', 'Unnamed: 10', 'ER', 'R', 'RISP', 'Balls',
#        'Unnamed: 15', 'Strikes', 'Ball', 'Strike', '1PK', 'Outs.1', 'pitch/ab',
#        'pitch/IP', 'A3P', '<=15', 'Strikes.1', 'COUNT', 'Unnamed: 27', 'P',
#        'LOM\nOut', 'LOM Scored', '1-2-3', '2&3', '0-1 R', 'FU IP'],
#       dtype='object')

# %%
June4 = June4.drop(columns=['#'])
June4 = June4.drop(columns= ['Unnamed: 15'])
June4 = June4.drop(columns= ['Unnamed: 10'])
June4 = June4.drop(columns=['Unnamed: 27'])

# %%
June4 = June4.rename(columns={ 
    'S/B' : 'SB',
    '<=15' : 'le15',
    'Strikes.1' : 'Strikes_1',
    'P #': 'P_num',
    'L/R':'LR',
    'E/DP' : 'E_DP',
    '1PK': 'One_PK',
    'Outs.1':'Outs_1',
    'pitch/ab':'pitch_ab',
    'pitch/IP':'pitch_IP',
    'LOM\nOut':'LOM_Out',
    'LOM Scored':'LOM_Scored',
    '1-2-3':'one_two_three',
    '2&3':'two_three',
    '0-1 R':'zero_one_R',
    'FU IP':'FU_IP'
})

# %%
June4 = June4.dropna(axis=1, how='all')

# %%
June4.columns
# Out:
# Index(['P_num', 'Pitcher', 'Outs', 'LR', 'Pitch', 'SB', 'Result', 'R', 'Balls',
#        'Strikes', 'Ball', 'Strike', 'One_PK', 'Outs_1', 'pitch_ab', 'pitch_IP',
#        'A3P', 'Strikes_1', 'COUNT'],
#       dtype='object')

# %%
June4 = June4.drop(columns=['Ball', 'Strike', 'A3P', 'Outs_1', 'Strikes_1', 'One_PK'])

# %%
June4['Date'] = '2025-06-04'
pd.to_datetime(June4['Date'], format='%Y-%m-%d')
# Out:
# 0     2025-06-04
# 1     2025-06-04
# 2     2025-06-04
# 3     2025-06-04
# 4     2025-06-04
#          ...
# 245   2025-06-04
# 246   2025-06-04
# 247   2025-06-04
# 248   2025-06-04
# 249   2025-06-04
# Name: Date, Length: 250, dtype: datetime64[ns]

# %%
June4 = June4[['Date'] + [col for col in June4.columns if col != 'Date']]

# %%
June4.head()
# Out:
#          Date  P_num Pitcher  Outs LR Pitch           SB Result    R  Balls  \
# 0  2025-06-04      1  Gibson   0.0  L    FB         Ball    NaN  NaN      0
# 1  2025-06-04      2  Gibson   0.0  L    FB          BIP     2B  NaN      1
# 2  2025-06-04      3  Gibson   0.0  R    FB          BIP      K  NaN      0
# 3  2025-06-04      4  Gibson   0.0  R    CH         Ball    NaN  NaN      0
# 4  2025-06-04      5  Gibson   1.0  R    FB  Strike-Take    NaN  NaN      1
#
#    Strikes  pitch_ab  pitch_IP COUNT
# 0        0         1         1   0-0
# 1        0         1         2   1-0
# 2        0         1         3   0-0
# 3        0         1         4   0-0
# 4        0         1         5   1-0

# %%
June4Velo = pd.read_csv('~/Downloads/Tomsox Data/Velocity Charts/ TomSox Velocity Chart  6-4-2025 - Chart.csv')
June4Velo = June4Velo[['Pitcher', 'Velocity', 'Spin Rate']]
June4merged = pd.merge(June4, June4Velo, on='Pitcher', how='left')

# %%
June4merged.to_csv('~/Downloads/Tomsox Data/TomSox 6-4-2025_merged.csv', index=False)

# %%
June7 = pd.read_csv('~/Downloads/Tomsox Data/Pitching Charts/TomSox 6-7-2025 Chart (Dropdown).csv')
June7.head()
# Out:
#    P # Pitcher  Inning  Outs   # L/R Pitch          S/B  Zone Result  ...  \
# 0    1  Lawson     1.0   0.0 NaN   R    FB         Ball   NaN    NaN  ...
# 1    2  Lawson     1.0   0.0 NaN   R    FB    Foul Ball   NaN    NaN  ...
# 2    3  Lawson     1.0   0.0 NaN   R    FB         Ball   NaN    NaN  ...
# 3    4  Lawson     1.0   0.0 NaN   R    SL  Strike-Take   NaN    NaN  ...
# 4    5  Lawson     1.0   0.0 NaN   R    SL         Ball   NaN    NaN  ...
#
#    Strikes.1  COUNT Unnamed: 27   P  LOM\nOut LOM Scored  1-2-3  2&3  0-1 R  \
# 0        NaN    0-0         NaN NaN       NaN        NaN    NaN  NaN    NaN
# 1        1.0    1-0         NaN NaN       NaN        NaN    NaN  NaN    NaN
# 2        NaN    1-1         NaN NaN       NaN        NaN    NaN  NaN    NaN
# 3        1.0    2-1         NaN NaN       NaN        NaN    NaN  NaN    NaN
# 4        NaN    2-2         NaN NaN       NaN        NaN    NaN  NaN    NaN
#
#    FU IP
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# ...

# %%
June7.columns
# Out:
# Index(['P #', 'Pitcher', 'Inning', 'Outs', '#', 'L/R', 'Pitch', 'S/B', 'Zone',
#        'Result', 'E/DP', 'ER', 'R', 'RISP', 'Balls', 'Unnamed: 15', 'Strikes',
#        'Ball', 'Strike', '1PK', 'Outs.1', 'pitch/ab', 'pitch/IP', 'A3P',
#        '<=15', 'Strikes.1', 'COUNT', 'Unnamed: 27', 'P', 'LOM\nOut',
#        'LOM Scored', '1-2-3', '2&3', '0-1 R', 'FU IP'],
#       dtype='object')

# %%
June7 = June7.drop(columns=['#'])
June7 = June7.drop(columns= ['Unnamed: 15'])
June7 = June7.drop(columns=['Unnamed: 27'])

# %%
June7.columns
# Out:
# Index(['P #', 'Pitcher', 'Inning', 'Outs', 'L/R', 'Pitch', 'S/B', 'Zone',
#        'Result', 'E/DP', 'ER', 'R', 'RISP', 'Balls', 'Strikes', 'Ball',
#        'Strike', '1PK', 'Outs.1', 'pitch/ab', 'pitch/IP', 'A3P', '<=15',
#        'Strikes.1', 'COUNT', 'P', 'LOM\nOut', 'LOM Scored', '1-2-3', '2&3',
#        '0-1 R', 'FU IP'],
#       dtype='object')

# %%
June7 = June7.rename(columns={ 
    'S/B' : 'SB',
    '<=15' : 'le15',
    'Strikes.1' : 'Strikes_1',
    'P #': 'P_num',
    'L/R':'LR',
    'E/DP' : 'E_DP',
    '1PK': 'One_PK',
    'Outs.1':'Outs_1',
    'pitch/ab':'pitch_ab',
    'pitch/IP':'pitch_IP',
    'LOM\nOut':'LOM_Out',
    'LOM Scored':'LOM_Scored',
    '1-2-3':'one_two_three',
    '2&3':'two_three',
    '0-1 R':'zero_one_R',
    'FU IP':'FU_IP'
})

# %%
June7.columns
# Out:
# Index(['P_num', 'Pitcher', 'Inning', 'Outs', 'LR', 'Pitch', 'SB', 'Zone',
#        'Result', 'E_DP', 'ER', 'R', 'RISP', 'Balls', 'Strikes', 'Ball',
#        'Strike', 'One_PK', 'Outs_1', 'pitch_ab', 'pitch_IP', 'A3P', 'le15',
#        'Strikes_1', 'COUNT', 'P', 'LOM_Out', 'LOM_Scored', 'one_two_three',
#        'two_three', 'zero_one_R', 'FU_IP'],
#       dtype='object')

# %%
June7 = June7.dropna(axis=1, how='all')

# %%
June7.columns
# Out:
# Index(['P_num', 'Pitcher', 'Inning', 'Outs', 'LR', 'Pitch', 'SB', 'Result',
#        'R', 'Balls', 'Strikes', 'Ball', 'Strike', 'One_PK', 'Outs_1',
#        'pitch_ab', 'pitch_IP', 'A3P', 'le15', 'Strikes_1', 'COUNT'],
#       dtype='object')

# %%
June7['Date'] = '2025-06-07'
pd.to_datetime(June7['Date'], format='%Y-%m-%d')
# Out:
# 0     2025-06-07
# 1     2025-06-07
# 2     2025-06-07
# 3     2025-06-07
# 4     2025-06-07
#          ...
# 245   2025-06-07
# 246   2025-06-07
# 247   2025-06-07
# 248   2025-06-07
# 249   2025-06-07
# Name: Date, Length: 250, dtype: datetime64[ns]

# %%
June7 = June7[['Date'] + [col for col in June7.columns if col != 'Date']]

# %%
June7 = June7.drop(columns=['Ball', 'Strike', 'A3P', 'Outs_1', 'Strikes_1', 'One_PK'])

# %%
June7.columns
# Out:
# Index(['Date', 'P_num', 'Pitcher', 'Inning', 'Outs', 'LR', 'Pitch', 'SB',
#        'Result', 'R', 'Balls', 'Strikes', 'pitch_ab', 'pitch_IP', 'le15',
#        'COUNT'],
#       dtype='object')

# %%
June7 = June7.drop(columns=['le15'])

# %%
June7Velo = pd.read_csv('~/Downloads/Tomsox Data/Velocity Charts/ TomSox Velocity Chart  6-7-2025 - Chart.csv')
June7Velo = June7Velo[['Pitcher', 'Velocity', 'Spin Rate']]
June7merged = pd.merge(June7, June7Velo, on='Pitcher', how='left')

# %%
June7merged.to_csv('~/Downloads/Tomsox Data/TomSox 6-7-2025_merged.csv', index=False)

# %%
May31 = pd.read_csv('~/Downloads/Tomsox Data/Pitching Charts/TomSox 5-31-2025- Chart (Dropdown).csv')

# %%
May31.columns
# Out:
# Index(['P #', 'Pitcher', 'Inning', 'Outs', '#', 'L/R', 'Pitch', 'S/B', 'Zone',
#        'Result', 'E/DP', 'ER', 'R', 'RISP', 'Balls', 'Unnamed: 15', 'Strikes',
#        'Ball', 'Strike', '1PK', 'Outs.1', 'pitch/ab', 'pitch/IP', 'A3P',
#        '<=15', 'Strikes.1', 'COUNT', 'Unnamed: 27', 'P', 'LOM\nOut',
#        'LOM Scored', '1-2-3', '2&3', '0-1 R', 'FU IP'],
#       dtype='object')

# %%
May31 = May31.drop(columns=['#'])
May31= May31.drop(columns= ['Unnamed: 15'])
May31 = May31.drop(columns=['Unnamed: 27'])

# %%
May31 = May31.rename(columns={ 
    'S/B' : 'SB',
    '<=15' : 'le15',
    'Strikes.1' : 'Strikes_1',
    'P #': 'P_num',
    'L/R':'LR',
    'E/DP' : 'E_DP',
    '1PK': 'One_PK',
    'Outs.1':'Outs_1',
    'pitch/ab':'pitch_ab',
    'pitch/IP':'pitch_IP',
    'LOM\nOut':'LOM_Out',
    'LOM Scored':'LOM_Scored',
    '1-2-3':'one_two_three',
    '2&3':'two_three',
    '0-1 R':'zero_one_R',
    'FU IP':'FU_IP'
})

# %%
May31 = May31.dropna(axis=1, how='all')

# %%
May31.columns
# Out:
# Index(['P_num', 'Pitcher', 'Inning', 'Outs', 'LR', 'Pitch', 'SB', 'Zone',
#        'Result', 'E_DP', 'R', 'Balls', 'Strikes', 'Ball', 'Strike', 'One_PK',
#        'Outs_1', 'pitch_ab', 'pitch_IP', 'A3P', 'le15', 'Strikes_1', 'COUNT'],
#       dtype='object')

# %%
May31 = May31.drop(columns=['Ball', 'Strike', 'A3P', 'Outs_1', 'Strikes_1', 'One_PK', 'le15'])

# %%
May31['Date'] = '2025-05-31'
pd.to_datetime(May31['Date'], format='%Y-%m-%d')
May31 = May31[['Date'] + [col for col in June7.columns if col != 'Date']]

# %%
May31.head()
# Out:
#          Date  P_num Pitcher  Inning  Outs LR Pitch    SB Result   R  Balls  \
# 0  2025-05-31      1    Link     1.0   0.0  R    FB  Ball    NaN NaN      0
# 1  2025-05-31      2    Link     1.0   0.0  R   NaN  Ball    NaN NaN      1
# 2  2025-05-31      3    Link     1.0   0.0  R   NaN  Ball    HBP NaN      2
# 3  2025-05-31      4    Link     1.0   0.0  R    FB   BIP     1B NaN      0
# 4  2025-05-31      5    Link     1.0   0.0  R    SL  Ball    NaN NaN      0
#
#    Strikes  pitch_ab  pitch_IP COUNT
# 0        0         1         1   0-0
# 1        0         1         2   1-0
# 2        0         1         3   2-0
# 3        0         1         4   0-0
# 4        0         1         5   0-0

# %%
May31Velo = pd.read_csv('~/Downloads/Tomsox Data/Velocity Charts/TomSox Velocity Chart  5-31-2025 - Chart.csv')
May31Velo.head()
# Out:
#    # Pitcher  Inning  Outs  #.1 L/R Pitch  Unnamed: 7  Velocity  Spin Rate
# 0  1    Link     1.0   0.0  NaN   R    FB         1.0      90.0        NaN
# 1  2    Link     1.0   0.0  NaN   R    FB         1.0      90.0        NaN
# 2  3    Link     1.0   0.0  NaN   R    FB         1.0      90.0        NaN
# 3  4    Link     1.0   0.0  NaN   R    FB         1.0      87.0        NaN
# 4  5    Link     1.0   0.0  NaN   L    SL         3.0      79.0        NaN

# %%
May31Velo = May31Velo[['Pitcher', 'Velocity', 'Spin Rate']]

# %%
May31merged = pd.merge(May31, May31Velo, on='Pitcher', how='left')

# %%
May31merged.head()
# Out:
#          Date  P_num Pitcher  Inning  Outs LR Pitch    SB Result   R  Balls  \
# 0  2025-05-31      1    Link     1.0   0.0  R    FB  Ball    NaN NaN      0
# 1  2025-05-31      1    Link     1.0   0.0  R    FB  Ball    NaN NaN      0
# 2  2025-05-31      1    Link     1.0   0.0  R    FB  Ball    NaN NaN      0
# 3  2025-05-31      1    Link     1.0   0.0  R    FB  Ball    NaN NaN      0
# 4  2025-05-31      1    Link     1.0   0.0  R    FB  Ball    NaN NaN      0
#
#    Strikes  pitch_ab  pitch_IP COUNT  Velocity  Spin Rate
# 0        0         1         1   0-0      90.0        NaN
# 1        0         1         1   0-0      90.0        NaN
# 2        0         1         1   0-0      90.0        NaN
# 3        0         1         1   0-0      87.0        NaN
# 4        0         1         1   0-0      79.0        NaN

# %%
May31merged.to_csv('~/Downloads/Tomsox Data/TomSox 05-31-2025_merged.csv', index=False)

# %%
June1 = pd.read_csv('~/Downloads/Tomsox Data/Pitching Charts/TomSox 6-1-2025 - Chart (Dropdown).csv')
June1 = June1.drop(columns=['#'])
June1= June1.drop(columns= ['Unnamed: 15'])
June1 = June1.drop(columns=['Unnamed: 27'])  
June1 = June1.rename(columns={ 
    'S/B' : 'SB',
    '<=15' : 'le15',
    'Strikes.1' : 'Strikes_1',
    'P #': 'P_num',
    'L/R':'LR',
    'E/DP' : 'E_DP',
    '1PK': 'One_PK',
    'Outs.1':'Outs_1',
    'pitch/ab':'pitch_ab',
    'pitch/IP':'pitch_IP',
    'LOM\nOut':'LOM_Out',
    'LOM Scored':'LOM_Scored',
    '1-2-3':'one_two_three',
    '2&3':'two_three',
    '0-1 R':'zero_one_R',
    'FU IP':'FU_IP'
})
June1 = June1.dropna(axis=1, how='all')
June1 = June1.drop(columns=['Ball', 'Strike', 'A3P', 'Outs_1', 'Strikes_1', 'One_PK', 'le15'])  
June1['Date'] = '2025-06-01'
pd.to_datetime(June1['Date'], format='%Y-%m-%d')
June1 = June1[['Date'] + [col for col in June7.columns if col != 'Date']]

June1Velo = pd.read_csv('~/Downloads/Tomsox Data/Velocity Charts/TomSox Velocity Chart  6-1-2025 - Chart.csv')
June1Velo = June1Velo[['Pitcher', 'Velocity', 'Spin Rate']]
June1merged = pd.merge(June1, June1Velo, on='Pitcher', how='left')

June1merged.to_csv('~/Downloads/Tomsox Data/TomSox 6-1-2025_merged.csv', index=False)

# %%
June3 = pd.read_csv('~/Downloads/Tomsox Data/Pitching Charts/ TomSox 6-3-2025 - Chart (Dropdown).csv')
June3 = June3.drop(columns=['#'])
June3= June3.drop(columns= ['Unnamed: 15'])
June3 = June3.drop(columns=['Unnamed: 27']) 
June3 = June3.drop(columns=['Unnamed: 10'])  
June3 = June3.rename(columns={ 
    'S/B' : 'SB',
    '<=15' : 'le15',
    'Strikes.1' : 'Strikes_1',
    'P #': 'P_num',
    'L/R':'LR',
    'E/DP' : 'E_DP',
    '1PK': 'One_PK',
    'Outs.1':'Outs_1',
    'pitch/ab':'pitch_ab',
    'pitch/IP':'pitch_IP',
    'LOM\nOut':'LOM_Out',
    'LOM Scored':'LOM_Scored',
    '1-2-3':'one_two_three',
    '2&3':'two_three',
    '0-1 R':'zero_one_R',
    'FU IP':'FU_IP'
})
June3.columns
# Out:
# Index(['P_num', 'Pitcher', 'Unnamed: 2', 'Outs', 'LR', 'Pitch', 'SB', 'Zone',
#        'Result', 'ER', 'R', 'RISP', 'Balls', 'Strikes', 'Ball', 'Strike',
#        'One_PK', 'Outs_1', 'pitch_ab', 'pitch_IP', 'A3P', 'le15', 'Strikes_1',
#        'COUNT', 'P', 'LOM_Out', 'LOM_Scored', 'one_two_three', 'two_three',
#        'zero_one_R', 'FU_IP'],
#       dtype='object')

# %%
cols_to_keep = ['R']
non_null_cols = June3.drop(columns=cols_to_keep).dropna(axis=1, how='all').columns

June3 = June3[cols_to_keep + list(non_null_cols)]

# %%
def move_column(df, col_name, new_index):
    cols = list(df.columns)
    cols.remove(col_name)
    cols.insert(new_index, col_name)
    return df[cols]

June3 = move_column(June3, 'R', 6)

# %%
June3 = June3.drop(columns=['Ball', 'Strike', 'A3P', 'Outs_1', 'Strikes_1', 'One_PK'])  
June3['Date'] = '2025-06-03'
pd.to_datetime(June3['Date'], format='%Y-%m-%d')
June3 = June3[['Date'] + [col for col in June3.columns if col != 'Date']]
June3.head()
# Out:
#          Date  P_num Pitcher Pitch           SB Zone Result   R  Balls  \
# 0  2025-06-03      1  Lawson    FB  Strike-Take  NaN    NaN NaN      0
# 1  2025-06-03      2  Lawson    FB    Foul Ball  NaN    NaN NaN      0
# 2  2025-06-03      3  Lawson    FB         Ball  NaN    NaN NaN      0
# 3  2025-06-03      4  Lawson    CH         Ball  NaN    NaN NaN      1
# 4  2025-06-03      5  Lawson    CB         Ball  NaN    NaN NaN      2
#
#    Strikes  pitch_ab  pitch_IP COUNT
# 0        0         1         1   0-0
# 1        1         2         2   0-1
# 2        2         3         3   0-2
# 3        2         4         4   1-2
# 4        2         5         5   2-2

# %%
June3Velo = pd.read_csv('~/Downloads/Tomsox Data/Velocity Charts/TomSox Velocity Chart  6-3-2025 - Chart.csv')
June3Velo = June3Velo[['Pitcher', 'Velocity', 'Spin Rate']]
June3merged = pd.merge(June3, June3Velo, on='Pitcher', how='left')

June3merged.to_csv('~/Downloads/Tomsox Data/TomSox 6-3-2025_merged.csv', index=False)

# %%
June6 = pd.read_csv('~/Downloads/Tomsox Data/Pitching Charts/TomSox 6-6-2025 - Chart (Dropdown).csv')
June6 = June6.drop(columns=['#'])
June6= June6.drop(columns= ['Unnamed: 15'])
June6 = June6.drop(columns=['Unnamed: 27'])  
June6 = June6.drop(columns=['Unnamed: 10']) 
June6 = June6.rename(columns={ 
    'S/B' : 'SB',
    '<=15' : 'le15',
    'Strikes.1' : 'Strikes_1',
    'P #': 'P_num',
    'L/R':'LR',
    'E/DP' : 'E_DP',
    '1PK': 'One_PK',
    'Outs.1':'Outs_1',
    'pitch/ab':'pitch_ab',
    'pitch/IP':'pitch_IP',
    'LOM\nOut':'LOM_Out',
    'LOM Scored':'LOM_Scored',
    '1-2-3':'one_two_three',
    '2&3':'two_three',
    '0-1 R':'zero_one_R',
    'FU IP':'FU_IP'
})
June6 = June6.dropna(axis=1, how='all')
June6 = June6.drop(columns=['Ball', 'Strike', 'A3P', 'Outs_1', 'Strikes_1', 'One_PK'])  
June6['Date'] = '2025-06-06'
pd.to_datetime(June6['Date'], format='%Y-%m-%d')
June6 = June6[['Date'] + [col for col in June6.columns if col != 'Date']]

June6.head()
# Out:
#          Date  P_num Pitcher  Outs Pitch         SB Result    R  Balls  \
# 0  2025-06-06      1    Link   0.0    FB       Ball    NaN  NaN      0
# 1  2025-06-06      2    Link   0.0    FB       Ball    NaN  NaN      1
# 2  2025-06-06      3    Link   0.0    FB     Strike    NaN  NaN      2
# 3  2025-06-06      4    Link   0.0    FB  Foul Ball    NaN  NaN      2
# 4  2025-06-06      5    Link   0.0    SL  Foul Ball    NaN  NaN      2
#
#    Strikes  pitch_ab  pitch_IP COUNT
# 0        0         1         1   0-0
# 1        0         2         2   1-0
# 2        0         3         3   2-0
# 3        1         4         4   2-1
# 4        2         5         5   2-2

# %%
June6Velo = pd.read_csv('~/Downloads/Tomsox Data/Velocity Charts/TomSox Velocity Chart  6-6-2025 - Chart.csv')
June6Velo = June1Velo[['Pitcher', 'Velocity', 'Spin Rate']]
June6merged = pd.merge(June6, June6Velo, on='Pitcher', how='left')

June6merged.to_csv('~/Downloads/Tomsox Data/TomSox 6-6-2025_merged.csv', index=False)

# %%
June10 = pd.read_csv('~/Downloads/Tomsox Data/Pitching Charts/ TomSox 6-10-2025 - Chart (Dropdown).csv')
June10 = June10.drop(columns=['#'])
June10= June10.drop(columns= ['Unnamed: 15'])
June10 = June10.drop(columns=['Unnamed: 27'])  
June10 = June10.rename(columns={ 
    'S/B' : 'SB',
    '<=15' : 'le15',
    'Strikes.1' : 'Strikes_1',
    'P #': 'P_num',
    'L/R':'LR',
    'E/DP' : 'E_DP',
    '1PK': 'One_PK',
    'Outs.1':'Outs_1',
    'pitch/ab':'pitch_ab',
    'pitch/IP':'pitch_IP',
    'LOM\nOut':'LOM_Out',
    'LOM Scored':'LOM_Scored',
    '1-2-3':'one_two_three',
    '2&3':'two_three',
    '0-1 R':'zero_one_R',
    'FU IP':'FU_IP'
})
June10 = June10.dropna(axis=1, how='all')
June10 = June10.drop(columns=['Ball', 'Strike', 'A3P', 'Outs_1', 'Strikes_1', 'One_PK'])  
June10['Date'] = '2025-06-10'
pd.to_datetime(June10['Date'], format='%Y-%m-%d')
June10 = June10[['Date'] + [col for col in June10.columns if col != 'Date']]

June10Velo = pd.read_csv('~/Downloads/Tomsox Data/Velocity Charts/ TomSox Velocity Chart  6-10-2025 - Chart.csv')
June10Velo = June1Velo[['Pitcher', 'Velocity', 'Spin Rate']]
June10merged = pd.merge(June10, June10Velo, on='Pitcher', how='left')

June10merged.to_csv('~/Downloads/Tomsox Data/TomSox 6-10-2025_merged.csv', index=False)

# %%
June11 = pd.read_csv('~/Downloads/Tomsox Data/Pitching Charts/TomSox 6-11-2025 - Chart (Dropdown).csv')
June11 = June11.drop(columns=['#'])
June11= June11.drop(columns= ['Unnamed: 15'])
June11 = June11.drop(columns=['Unnamed: 27'])  
June11 = June11.rename(columns={ 
    'S/B' : 'SB',
    '<=15' : 'le15',
    'Strikes.1' : 'Strikes_1',
    'P #': 'P_num',
    'L/R':'LR',
    'E/DP' : 'E_DP',
    '1PK': 'One_PK',
    'Outs.1':'Outs_1',
    'pitch/ab':'pitch_ab',
    'pitch/IP':'pitch_IP',
    'LOM\nOut':'LOM_Out',
    'LOM Scored':'LOM_Scored',
    '1-2-3':'one_two_three',
    '2&3':'two_three',
    '0-1 R':'zero_one_R',
    'FU IP':'FU_IP'
})
June11 = June11.dropna(axis=1, how='all')
June11 = June11.drop(columns=['Ball', 'Strike', 'A3P', 'Outs_1', 'Strikes_1', 'One_PK', 'le15'])  
June11['Date'] = '2025-06-11'
pd.to_datetime(June11['Date'], format='%Y-%m-%d')
June11 = June11[['Date'] + [col for col in June11.columns if col != 'Date']]

June11Velo = pd.read_csv('~/Downloads/Tomsox Data/Velocity Charts/TomSox Velocity Chart  6-11-2025 - Chart.csv')
June11Velo = June11Velo[['Pitcher', 'Velocity', 'Spin Rate']]
June11merged = pd.merge(June11, June11Velo, on='Pitcher', how='left')

June11merged.to_csv('~/Downloads/Tomsox Data/TomSox 6-11-2025_merged.csv', index=False)

# %%
June12 = pd.read_csv('~/Downloads/Tomsox Data/Pitching Charts/ TomSox 6-12-2025 - Chart (Dropdown).csv')
June12 = June12.drop(columns=['#'])
June12= June12.drop(columns= ['Unnamed: 15'])
June12 = June12.drop(columns=['Unnamed: 27'])  
June12 = June12.rename(columns={ 
    'S/B' : 'SB',
    '<=15' : 'le15',
    'Strikes.1' : 'Strikes_1',
    'P #': 'P_num',
    'L/R':'LR',
    'E/DP' : 'E_DP',
    '1PK': 'One_PK',
    'Outs.1':'Outs_1',
    'pitch/ab':'pitch_ab',
    'pitch/IP':'pitch_IP',
    'LOM\nOut':'LOM_Out',
    'LOM Scored':'LOM_Scored',
    '1-2-3':'one_two_three',
    '2&3':'two_three',
    '0-1 R':'zero_one_R',
    'FU IP':'FU_IP'
})
June12 = June12.dropna(axis=1, how='all')
June12 = June12.drop(columns=['Ball', 'Strike', 'A3P', 'Outs_1', 'Strikes_1', 'One_PK', 'le15'])  
June12['Date'] = '2025-06-12'
pd.to_datetime(June12['Date'], format='%Y-%m-%d')
June12 = June12[['Date'] + [col for col in June12.columns if col != 'Date']]

June12Velo = pd.read_csv('~/Downloads/Tomsox Data/Velocity Charts/TomSox Velocity Chart  6-12-2025 - Chart.csv')
June12Velo = June11Velo[['Pitcher', 'Velocity', 'Spin Rate']]
June12merged = pd.merge(June12, June12Velo, on='Pitcher', how='left')

June12merged.to_csv('~/Downloads/Tomsox Data/TomSox 6-12-2025_merged.csv', index=False)
